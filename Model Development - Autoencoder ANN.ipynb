# %%
import json
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import RobustScaler, StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_curve, davies_bouldin_score, calinski_harabasz_score

import time
import psutil
import threading
from memory_profiler import memory_usage

# %% [markdown]
# # functions

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, f1_score

def compute_roc(y_true, y_scores):
    """
    Computes ROC curve and AUC from the true labels and predicted scores.
    
    Parameters:
    y_true (list or array): True binary labels (0 or 1)
    y_scores (list or array): Predicted probability scores
    
    Returns:
    fpr: False positive rate
    tpr: True positive rate
    roc_auc: Area under the ROC curve
    """
    # Compute FPR, TPR, and thresholds using sklearn's roc_curve
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)
    
    # Compute the AUC (Area Under the Curve)
    roc_auc = auc(fpr, tpr)
    
    return fpr, tpr, roc_auc


def plot_roc_curve(fpr, tpr, roc_auc, title=None):
    """
    Plots the ROC curve with the given FPR, TPR and AUC.
    
    Parameters:
    fpr: False positive rate
    tpr: True positive rate
    roc_auc: Area under the ROC curve
    title: Title of the plot (optional)
    """
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', label=f'ROC curve (AUC = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')  # Diagonal line
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(title if title else 'Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()


def compute_pr_auc(y_true, y_scores):
    """
    Computes Precision-Recall curve and AUC from true labels and predicted scores.
    
    Parameters:
    y_true (list or array): True binary labels (0 or 1)
    y_scores (list or array): Predicted probability scores
    
    Returns:
    precision: Precision values
    recall: Recall values
    pr_auc: Area under the Precision-Recall curve
    """
    # Compute precision, recall, and thresholds using sklearn's precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
    
    # Compute the AUC (Area Under the Curve) for precision-recall
    pr_auc = auc(recall, precision)
    
    return precision, recall, pr_auc, thresholds


def plot_pr_curve(precision, recall, pr_auc, title=None):
    """
    Plots the Precision-Recall curve with the given precision, recall, and AUC.
    
    Parameters:
    precision: Precision values
    recall: Recall values
    pr_auc: Area under the Precision-Recall curve
    title: Title of the plot (optional)
    """
    plt.figure()
    plt.plot(recall, precision, color='blue', lw=2, label=f'PR curve (AUC = {pr_auc:.4f})')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(title if title else 'Precision-Recall Curve')
    plt.legend(loc="lower left")
    plt.show()

# %% [markdown]
# # loading processed dataset

# %%
with open('preprocessing_df_config.json', 'r') as f:
    config = json.load(f)

# %%
dataset_folder = 'dataset'
df = pd.read_parquet(os.path.join(dataset_folder, 'dataset_processed.parquet'))
df = df.drop(columns=config['columns_to_drop'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787102 entries, 0 to 787101
# Data columns (total 76 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Destination Port               787102 non-null  int64
#  1   Flow Duration                  787102 non-null  int64
#  2   Total Fwd Packets              787102 non-null  int64
#  3   Total Backward Packets         787102 non-null  int64
#  4   Total Length of Bwd Packets    787102 non-null  int64
#  5   Fwd Packet Length Max          787102 non-null  int64
#  6   Fwd Packet Length Min          787102 non-null  int64
#  7   Fwd Packet Length Std          787102 non-null  float64
#  8   Bwd Packet Length Max          787102 non-null  int64
#  9   Bwd Packet Length Min          787102 non-null  int64
#  10  Bwd Packet Length Std          787102 non-null  float64
#  11  Flow Bytes/s                   787102 non-null  float64
#  12  Flow Packets/s                 787102 non-null  float64
#  13  Flow IAT Mean                  787102 non-null  float64
#  14  Flow IAT Std                   787102 non-null  float64
#  15  Flow IAT Max                   787102 non-null  int64
#  16  Flow IAT Min                   787102 non-null  int64
#  17  Fwd IAT Total                  787102 non-null  int64
#  18  Fwd IAT Mean                   787102 non-null  float64
#  19  Fwd IAT Std                    787102 non-null  float64
#  20  Fwd IAT Max                    787102 non-null  int64
#  21  Fwd IAT Min                    787102 non-null  int64
#  22  Bwd IAT Total                  787102 non-null  int64
#  23  Bwd IAT Mean                   787102 non-null  float64
#  24  Bwd IAT Std                    787102 non-null  float64
#  25  Bwd IAT Max                    787102 non-null  int64
#  26  Bwd IAT Min                    787102 non-null  int64
#  27  Fwd PSH Flags                  787102 non-null  int64
#  28  Fwd URG Flags                  787102 non-null  int64
#  29  Fwd Header Length              787102 non-null  int64
#  30  Bwd Header Length              787102 non-null  int64
#  31  Fwd Packets/s                  787102 non-null  float64
#  32  Bwd Packets/s                  787102 non-null  float64
#  33  Min Packet Length              787102 non-null  int64
#  34  Max Packet Length              787102 non-null  int64
#  35  Packet Length Mean             787102 non-null  float64
#  36  Packet Length Std              787102 non-null  float64
#  37  Packet Length Variance         787102 non-null  float64
#  38  FIN Flag Count                 787102 non-null  int64
#  39  RST Flag Count                 787102 non-null  int64
#  40  PSH Flag Count                 787102 non-null  int64
#  41  ACK Flag Count                 787102 non-null  int64
#  42  URG Flag Count                 787102 non-null  int64
#  43  ECE Flag Count                 787102 non-null  int64
#  44  Down/Up Ratio                  787102 non-null  int64
#  45  Average Packet Size            787102 non-null  float64
#  46  Avg Fwd Segment Size           787102 non-null  float64
#  47  Avg Bwd Segment Size           787102 non-null  float64
#  48  Subflow Fwd Bytes              787102 non-null  int64
#  49  Init_Win_bytes_forward         787102 non-null  int64
#  50  Init_Win_bytes_backward        787102 non-null  int64
#  51  act_data_pkt_fwd               787102 non-null  int64
#  52  min_seg_size_forward           787102 non-null  int64
#  53  Active Mean                    787102 non-null  float64
#  54  Active Std                     787102 non-null  float64
#  55  Active Max                     787102 non-null  int64
#  56  Active Min                     787102 non-null  int64
#  57  Idle Mean                      787102 non-null  float64
#  58  Idle Std                       787102 non-null  float64
#  59  Idle Max                       787102 non-null  int64
#  60  Idle Min                       787102 non-null  int64
#  61  Label                          787102 non-null  object
#  62  anomaly                        787102 non-null  int64
#  63  bytes_per_packet               787102 non-null  float64
#  64  packet_rate_ratio              787102 non-null  float64
#  65  fwd_bwd_packet_ratio           787102 non-null  float64
#  66  direction_dominance            787102 non-null  float64
#  67  packet_density                 787102 non-null  float64
#  68  iat_variability                787102 non-null  float64
#  69  syn_ratio                      787102 non-null  float64
#  70  ack_ratio                      787102 non-null  float64
#  71  payload_efficiency             787102 non-null  float64
#  72  Flow Bytes/s_log               787102 non-null  float64
#  73  Flow Packets/s_log             787102 non-null  float64
#  74  Flow Duration_log              787102 non-null  float64
#  75  Destination Port Distribution  787102 non-null  float64
# dtypes: float64(35), int64(40), object(1)
# memory usage: 456.4+ MB

# %% [markdown]
# # splitting dataset

# %%
# data to be used will be one with benign/false anomalies

# Preparing features and truth labels
X = df.drop(['Label','anomaly',], axis=1)
y = df['anomaly']

# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train = X_train[y_train == 0]
y_train = y_train[y_train == 0]

# %% [markdown]
# # scaling dataset

# %%
# Initializing StandardScaler
scaler = StandardScaler()

# Fit and transform the training data
X_train_scaled = scaler.fit_transform(X_train)

# Transform the test and validation set using the fitted scaler
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # AutoEncoder Iteration 1

# %% [markdown]
# ## defining autoencoder architecture

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

def build_autoencoder(input_dim: int, bottleneck: int = 8,
                      dropout_rate: float = 0.2, l2_reg: float = 1e-4):
    inputs = Input(shape=(input_dim,))

    # Encoder
    x = Dense(128, kernel_regularizer=l2(l2_reg))(inputs)  # wider first layer
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(64, kernel_regularizer=l2(l2_reg))(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(32, kernel_regularizer=l2(l2_reg))(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    x = Dense(16, kernel_regularizer=l2(l2_reg))(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    # Bottleneck — increased from 4 to 8
    bottleneck_layer = Dense(bottleneck, activation='relu', name='bottleneck')(x)

    # Decoder — mirror of encoder
    x = Dense(16, kernel_regularizer=l2(l2_reg))(bottleneck_layer)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    x = Dense(32, kernel_regularizer=l2(l2_reg))(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(64, kernel_regularizer=l2(l2_reg))(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(128, kernel_regularizer=l2(l2_reg))(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    outputs = Dense(input_dim, activation='linear', name='reconstruction')(x)
    model = Model(inputs, outputs, name='autoencoder')
    return model


# Build & compile
tf.keras.backend.clear_session()
model = build_autoencoder(input_dim=X.shape[1], dropout_rate=0.3)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3,clipnorm=1.0),
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Nathaniel\Projects\learning-sandbox\aim-capstone\.venv\lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 74)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         9,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_3 (ReLU)                  │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bottleneck (Dense)              │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_6 (ReLU)                  │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_7 (ReLU)                  │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reconstruction (Dense)          │ (None, 74)             │         9,546 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 43,186 (168.70 KB)
#  Trainable params: 42,226 (164.95 KB)
#  Non-trainable params: 960 (3.75 KB)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

def build_autoencoder(input_dim: int, bottleneck: int = 8,
                      dropout_rate: float = 0.2,):
    inputs = Input(shape=(input_dim,))

    # Encoder
    # x = Dense(128)(inputs)  # wider first layer
    # x = BatchNormalization()(x)
    # x = tf.keras.activations.relu(x)
    # x = Dropout(dropout_rate)(x)

    x = Dense(64)(inputs)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(32)(x)
    # x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    x = Dense(16)(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    # Bottleneck — increased from 4 to 8
    bottleneck_layer = Dense(bottleneck, activation='relu', name='bottleneck')(x)

    # Decoder — mirror of encoder
    x = Dense(16)(bottleneck_layer)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    x = Dense(32)(x)
    # x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(64)(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = Dropout(dropout_rate)(x)

    # x = Dense(128)(x)
    # x = BatchNormalization()(x)
    # x = tf.keras.activations.relu(x)

    outputs = Dense(input_dim, activation='linear', name='reconstruction')(x)
    model = Model(inputs, outputs, name='autoencoder')
    return model


# Build & compile
tf.keras.backend.clear_session()
model = build_autoencoder(input_dim=74, dropout_rate=0.1)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3,clipnorm=1.0),
    loss='mse',
    metrics=['mae']
)

model.summary()

# %%
# split the train dataset to have validation dataset
X_train_final, X_val = train_test_split(
    X_train_scaled, test_size=0.2, random_state=42, shuffle=True
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=1e-6,
    patience=20,
    verbose=1,
    restore_best_weights=True,
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1
)

history = model.fit(
    X_train_final, X_train_final,
    validation_data=(X_val, X_val),
    batch_size=512,
    epochs=300,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

# ── Better plotting ───────────────────────────────────────
import matplotlib.pyplot as plt

hist_df = pd.DataFrame(history.history)

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

# Loss
hist_df[['loss', 'val_loss']].plot(ax=axes[0])
axes[0].set_title('MSE Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')

# MAE
hist_df[['mae', 'val_mae']].plot(ax=axes[1])
axes[1].set_title('MAE')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('MAE')

plt.tight_layout()
plt.show()

# ── Sanity checks ─────────────────────────────────────────
print(f"Best val_loss:  {hist_df['val_loss'].min():.6f} at epoch {hist_df['val_loss'].idxmin()}")
print(f"Final val_loss: {hist_df['val_loss'].iloc[-1]:.6f}")
print(f"Stopped at epoch: {len(hist_df)}")
# Out:
# Epoch 1/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - loss: 0.6827 - mae: 0.2748 - val_loss: 0.4396 - val_mae: 0.1743 - learning_rate: 0.0010
# Epoch 2/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 0.5018 - mae: 0.2101 - val_loss: 0.3299 - val_mae: 0.1600 - learning_rate: 0.0010
# Epoch 3/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - loss: 0.4372 - mae: 0.1995 - val_loss: 0.3675 - val_mae: 0.1506 - learning_rate: 0.0010
# Epoch 4/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - loss: 0.4101 - mae: 0.1922 - val_loss: 0.2806 - val_mae: 0.1380 - learning_rate: 0.0010
# Epoch 5/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.3905 - mae: 0.1878 - val_loss: 0.3013 - val_mae: 0.1426 - learning_rate: 0.0010
# Epoch 6/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.3789 - mae: 0.1852 - val_loss: 0.2565 - val_mae: 0.1354 - learning_rate: 0.0010
# Epoch 7/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - loss: 0.3684 - mae: 0.1841 - val_loss: 0.2608 - val_mae: 0.1441 - learning_rate: 0.0010
# Epoch 8/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - loss: 0.3599 - mae: 0.1837 - val_loss: 0.2569 - val_mae: 0.1326 - learning_rate: 0.0010
# Epoch 9/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.3521 - mae: 0.1806 - val_loss: 0.2768 - val_mae: 0.1485 - learning_rate: 0.0010
# Epoch 10/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.3448 - mae: 0.1798 - val_loss: 0.2607 - val_mae: 0.1339 - learning_rate: 0.0010
# Epoch 11/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.3410 - mae: 0.1792 - val_loss: 0.2506 - val_mae: 0.1374 - learning_rate: 0.0010
# Epoch 12/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.3333 - mae: 0.1782 - val_loss: 0.2368 - val_mae: 0.1342 - learning_rate: 0.0010
# Epoch 13/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - loss: 0.3269 - mae: 0.1781 - val_loss: 0.2542 - val_mae: 0.1507 - learning_rate: 0.0010
# Epoch 14/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - loss: 0.3234 - mae: 0.1779 - val_loss: 0.2427 - val_mae: 0.1494 - learning_rate: 0.0010
# Epoch 15/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - loss: 0.3212 - mae: 0.1764 - val_loss: 0.2669 - val_mae: 0.1451 - learning_rate: 0.0010
# Epoch 16/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.3194 - mae: 0.1766 - val_loss: 0.2645 - val_mae: 0.1465 - learning_rate: 0.0010
# Epoch 17/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.3042 - mae: 0.1771 - val_loss: 0.2494 - val_mae: 0.1338 - learning_rate: 0.0010
# Epoch 18/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.3114 - mae: 0.1756 - val_loss: 0.2569 - val_mae: 0.1499 - learning_rate: 0.0010
# Epoch 19/300
# 705/709 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2620 - mae: 0.1740
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.3047 - mae: 0.1755 - val_loss: 0.2754 - val_mae: 0.1471 - learning_rate: 0.0010
# Epoch 20/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.2963 - mae: 0.1722 - val_loss: 0.2285 - val_mae: 0.1303 - learning_rate: 5.0000e-04
# Epoch 21/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.2990 - mae: 0.1703 - val_loss: 0.2496 - val_mae: 0.1379 - learning_rate: 5.0000e-04
# Epoch 22/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.2846 - mae: 0.1707 - val_loss: 0.2435 - val_mae: 0.1385 - learning_rate: 5.0000e-04
# Epoch 23/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2866 - mae: 0.1704 - val_loss: 0.2502 - val_mae: 0.1374 - learning_rate: 5.0000e-04
# Epoch 24/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.2814 - mae: 0.1709 - val_loss: 0.2674 - val_mae: 0.1406 - learning_rate: 5.0000e-04
# Epoch 25/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2882 - mae: 0.1699 - val_loss: 0.2425 - val_mae: 0.1382 - learning_rate: 5.0000e-04
# Epoch 26/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2716 - mae: 0.1700 - val_loss: 0.2398 - val_mae: 0.1376 - learning_rate: 5.0000e-04
# Epoch 27/300
# 706/709 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2679 - mae: 0.1684
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - loss: 0.2710 - mae: 0.1700 - val_loss: 0.2333 - val_mae: 0.1345 - learning_rate: 5.0000e-04
# Epoch 28/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2653 - mae: 0.1671 - val_loss: 0.2480 - val_mae: 0.1367 - learning_rate: 2.5000e-04
# Epoch 29/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - loss: 0.2621 - mae: 0.1663 - val_loss: 0.2389 - val_mae: 0.1327 - learning_rate: 2.5000e-04
# Epoch 30/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - loss: 0.2677 - mae: 0.1667 - val_loss: 0.2418 - val_mae: 0.1356 - learning_rate: 2.5000e-04
# Epoch 31/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2655 - mae: 0.1667 - val_loss: 0.2255 - val_mae: 0.1306 - learning_rate: 2.5000e-04
# Epoch 32/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 0.2644 - mae: 0.1659 - val_loss: 0.2600 - val_mae: 0.1419 - learning_rate: 2.5000e-04
# Epoch 33/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 0.2663 - mae: 0.1665 - val_loss: 0.2425 - val_mae: 0.1372 - learning_rate: 2.5000e-04
# Epoch 34/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2720 - mae: 0.1664 - val_loss: 0.2690 - val_mae: 0.1458 - learning_rate: 2.5000e-04
# Epoch 35/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2635 - mae: 0.1662 - val_loss: 0.2311 - val_mae: 0.1320 - learning_rate: 2.5000e-04
# Epoch 36/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2625 - mae: 0.1659 - val_loss: 0.2482 - val_mae: 0.1378 - learning_rate: 2.5000e-04
# Epoch 37/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2616 - mae: 0.1663 - val_loss: 0.2344 - val_mae: 0.1342 - learning_rate: 2.5000e-04
# Epoch 38/300
# 708/709 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3374 - mae: 0.1658
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2628 - mae: 0.1659 - val_loss: 0.2475 - val_mae: 0.1356 - learning_rate: 2.5000e-04
# Epoch 39/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2667 - mae: 0.1641 - val_loss: 0.2309 - val_mae: 0.1308 - learning_rate: 1.2500e-04
# Epoch 40/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.2575 - mae: 0.1641 - val_loss: 0.2392 - val_mae: 0.1364 - learning_rate: 1.2500e-04
# Epoch 41/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.2595 - mae: 0.1641 - val_loss: 0.2345 - val_mae: 0.1341 - learning_rate: 1.2500e-04
# Epoch 42/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2579 - mae: 0.1639 - val_loss: 0.2298 - val_mae: 0.1325 - learning_rate: 1.2500e-04
# Epoch 43/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.2562 - mae: 0.1643 - val_loss: 0.2343 - val_mae: 0.1347 - learning_rate: 1.2500e-04
# Epoch 44/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2612 - mae: 0.1639 - val_loss: 0.2294 - val_mae: 0.1333 - learning_rate: 1.2500e-04
# Epoch 45/300
# 708/709 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2652 - mae: 0.1641
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - loss: 0.2551 - mae: 0.1638 - val_loss: 0.2351 - val_mae: 0.1358 - learning_rate: 1.2500e-04
# Epoch 46/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2615 - mae: 0.1632 - val_loss: 0.2316 - val_mae: 0.1326 - learning_rate: 6.2500e-05
# Epoch 47/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2567 - mae: 0.1625 - val_loss: 0.2304 - val_mae: 0.1307 - learning_rate: 6.2500e-05
# Epoch 48/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.2546 - mae: 0.1626 - val_loss: 0.2302 - val_mae: 0.1312 - learning_rate: 6.2500e-05
# Epoch 49/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - loss: 0.2546 - mae: 0.1623 - val_loss: 0.2438 - val_mae: 0.1370 - learning_rate: 6.2500e-05
# Epoch 50/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.2508 - mae: 0.1625 - val_loss: 0.2779 - val_mae: 0.1476 - learning_rate: 6.2500e-05
# Epoch 51/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.2582 - mae: 0.1626 - val_loss: 0.2356 - val_mae: 0.1328 - learning_rate: 6.2500e-05
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 31.
# Best val_loss:  0.225529 at epoch 30
# Final val_loss: 0.235646
# Stopped at epoch: 51

# %% [markdown]
# ## validation of train-val results

# %%
# After training, run this to evaluate
train_recon = model.predict(X_train_final, batch_size=512)
val_recon   = model.predict(X_val, batch_size=512)

train_mse = np.mean(np.square(X_train_final - train_recon))
val_mse   = np.mean(np.square(X_val - val_recon))

print(f"Train MSE: {train_mse:.4f}")   # target: < 0.15
print(f"Val MSE:   {val_mse:.4f}")     # target: < 0.15
print(f"Gap:       {abs(val_mse - train_mse):.4f}")  # target: < 0.05
# Out:
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Train MSE: 0.2590
# Val MSE:   0.2126
# Gap:       0.0464

# %% [markdown]
# ## save model to reduce headache

# %%
model.save('ann4-nice.keras')

# %% [markdown]
# ## testing model performance

# %% [markdown]
# ### feature analysis

# %%
train_recon = model.predict(X_train_final, batch_size=512)
errors_per_feature = np.mean(np.square(X_train_final - train_recon), axis=0)
feature_errors = pd.Series(errors_per_feature, index=X.columns).sort_values(ascending=False)

print("Top 10 worst reconstructed features:")
print(feature_errors.head(10))
print("\nBottom 10 best reconstructed features:")
print(feature_errors.tail(10))
# Out:
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# Top 10 worst reconstructed features:
# Fwd Header Length              1.239102
# min_seg_size_forward           1.212342
# Subflow Fwd Bytes              1.172421
# Fwd URG Flags                  0.931663
# act_data_pkt_fwd               0.778765
# Bwd Header Length              0.692581
# Total Length of Bwd Packets    0.663490
# iat_variability                0.659204
# Total Backward Packets         0.645223
# Total Fwd Packets              0.643522
# dtype: float64
#
# Bottom 10 best reconstructed features:
# Avg Fwd Segment Size     0.093479
# Flow IAT Min             0.086922
# Flow Packets/s_log       0.086846
# Bwd IAT Total            0.078152
# Fwd Packet Length Min    0.073934
# FIN Flag Count           0.073272
# Flow Duration_log        0.064282
# Fwd IAT Total            0.060600
# ack_ratio                0.058991
# Flow Duration            0.054454
# dtype: float64

# %% [markdown]
# ### Error Analysis

# %%
# ── 1. Compute reconstruction error on NORMAL training data ──
train_recon = model.predict(X_train_final, batch_size=512)
train_errors = np.mean(np.square(X_train_final - train_recon), axis=1)
# shape: (385482,) — one error score per sample
# ── 2. Visualize the error distribution ──

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.hist(train_errors, bins=100, edgecolor='black', log=True)
plt.title('Reconstruction Error Distribution (Training Data)')
plt.xlabel('MSE per Sample')
plt.ylabel('Count')
plt.axvline(np.percentile(train_errors, 95), color='orange', linestyle='--', label='95th percentile')
plt.axvline(np.percentile(train_errors, 99), color='red',    linestyle='--', label='99th percentile')
plt.legend()
plt.tight_layout()
plt.show()

# ── 3. Check percentile values ──
for p in [90, 95, 99, 99.5]:
    print(f"Percentile {p:5.1f}: {np.percentile(train_errors, p):.4f}")
# Out:
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step
# Percentile  90.0: 0.2601
# Percentile  95.0: 0.5714
# Percentile  99.0: 1.8232
# Percentile  99.5: 2.3963

# %%
# ── 5. Score your test data ──
test_recon  = model.predict(X_test_scaled, batch_size=512)
test_errors = np.mean(np.square(X_test_scaled - test_recon), axis=1)
# Out:
# Anomaly threshold: 1.8232
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Total test samples:  236131
# Anomalies detected:  20602 (8.72%)

# %% [markdown]
# ### ROC and PR Curves

# %%
actual_anomaly = y_test

fpr, tpr, roc_auc = compute_roc(
    actual_anomaly,
    test_errors)

# Plot ROC curve
plot_roc_curve(fpr, tpr, roc_auc, title='ROC curve')


precision, recall, pr_auc, threshold = compute_pr_auc(
    actual_anomaly,
    test_errors)
f1_scores = 2 * recall * precision / (recall + precision)
print('Best threshold: ', threshold[np.argmax(f1_scores[~np.isnan(f1_scores)])])
print('Best F1-Score: ', np.max(f1_scores[~np.isnan(f1_scores)]))
# Plot ROC curve
plot_pr_curve(precision, recall, pr_auc, title='PR curve')
# Out:
# Best threshold:  1.097174279820258
# Best F1-Score:  0.6309196137651942
# C:\Users\Nathaniel\AppData\Local\Temp\ipykernel_15112\3851632075.py:14: RuntimeWarning: invalid value encountered in divide
#   f1_scores = 2 * recall * precision / (recall + precision)

# %% [markdown]
# ### Recall vs Precision across threshold

# %%
plt.figure(figsize=(8, 6))
plt.plot(threshold, recall[:-1], label='Recall', color='red', linewidth=2,)
plt.plot(threshold, precision[:-1], label='Precision', color='blue', linewidth=2,)
plt.xscale('log')
plt.legend()

# %% [markdown]
# ### finding threshold and classification of anomalies

# %%
from sklearn.metrics import roc_curve, f1_score

# Compute ROC curve to determine optimal threshold for binary classification
fpr, tpr, thresholds = roc_curve(y_test, test_errors)

# optimal threshold by max f1 score
optimal_threshold = threshold[np.argmax(f1_scores[~np.isnan(f1_scores)])]
print(f'Optimal Threshold: {optimal_threshold}')

# Classify anomalies
y_pred_if = (test_errors >= optimal_threshold).astype(int)
# Out:
# Optimal Threshold: 1.097174279820258

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report

# target_names allows you to label the output for better readability
print(classification_report(y_test, y_pred_if, target_names=['Normal', 'Anomaly'],))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.98      0.94    194558
#      Anomaly       0.83      0.51      0.63     41573
#
#     accuracy                           0.89    236131
#    macro avg       0.87      0.74      0.78    236131
# weighted avg       0.89      0.89      0.88    236131

# %% [markdown]
# ### Confusion Matrix

# %%
# Confusion Matrix for Binary Classification
cm_kmeans = confusion_matrix(y_test, y_pred_if)

plt.figure(figsize=(8, 6))
sns.heatmap(cm_kmeans, annot=True, fmt='d', 
            xticklabels=['Normal', 'Attack'], 
            yticklabels=['Normal', 'Attack'], 
            cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Isolation Forest - 1st Iteration Confusion Matrix')
plt.show()

# %% [markdown]
# # AutoEncoder Iteration 2

# %% [markdown]
# ## defining autoencoder architecture

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

def build_autoencoder(input_dim: int, bottleneck: int = 8,
                      dropout_rate: float = 0.2,):
    inputs = Input(shape=(input_dim,))

    # Encoder
    x = Dense(64)(inputs)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(32)(x)
    # x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    x = Dense(16)(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    # Bottleneck — increased from 4 to 8
    bottleneck_layer = Dense(bottleneck, activation='relu', name='bottleneck')(x)

    # Decoder — mirror of encoder
    x = Dense(16)(bottleneck_layer)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    x = Dense(32)(x)
    # x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(64)(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = Dropout(dropout_rate)(x)


    outputs = Dense(input_dim, activation='linear', name='reconstruction')(x)
    model = Model(inputs, outputs, name='autoencoder')
    return model


# Build & compile
tf.keras.backend.clear_session()
model = build_autoencoder(input_dim=74, dropout_rate=0.1)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3,clipnorm=1.0),
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 74)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bottleneck (Dense)              │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_3 (ReLU)                  │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reconstruction (Dense)          │ (None, 74)             │         4,810 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,794 (61.70 KB)
#  Trainable params: 15,474 (60.45 KB)
#  Non-trainable params: 320 (1.25 KB)

# %%
# split the train dataset to have validation dataset
X_train_final, X_val = train_test_split(
    X_train_scaled, test_size=0.2, random_state=42, shuffle=True
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=1e-6,
    patience=20,
    verbose=1,
    restore_best_weights=True,
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1
)

history = model.fit(
    X_train_final, X_train_final,
    validation_data=(X_val, X_val),
    batch_size=512,
    epochs=300,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

# ── Better plotting ───────────────────────────────────────
import matplotlib.pyplot as plt

hist_df = pd.DataFrame(history.history)

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

# Loss
hist_df[['loss', 'val_loss']].plot(ax=axes[0])
axes[0].set_title('MSE Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')

# MAE
hist_df[['mae', 'val_mae']].plot(ax=axes[1])
axes[1].set_title('MAE')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('MAE')

plt.tight_layout()
plt.show()

# ── Sanity checks ─────────────────────────────────────────
print(f"Best val_loss:  {hist_df['val_loss'].min():.6f} at epoch {hist_df['val_loss'].idxmin()}")
print(f"Final val_loss: {hist_df['val_loss'].iloc[-1]:.6f}")
print(f"Stopped at epoch: {len(hist_df)}")
# Out:
# Epoch 1/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.5526 - mae: 0.2675 - val_loss: 0.3103 - val_mae: 0.1673 - learning_rate: 0.0010
# Epoch 2/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.3708 - mae: 0.2047 - val_loss: 0.2181 - val_mae: 0.1357 - learning_rate: 0.0010
# Epoch 3/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.3325 - mae: 0.1949 - val_loss: 0.1942 - val_mae: 0.1340 - learning_rate: 0.0010
# Epoch 4/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.3083 - mae: 0.1891 - val_loss: 0.1690 - val_mae: 0.1216 - learning_rate: 0.0010
# Epoch 5/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2949 - mae: 0.1839 - val_loss: 0.1607 - val_mae: 0.1218 - learning_rate: 0.0010
# Epoch 6/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2864 - mae: 0.1806 - val_loss: 0.1478 - val_mae: 0.1154 - learning_rate: 0.0010
# Epoch 7/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2796 - mae: 0.1767 - val_loss: 0.1405 - val_mae: 0.1150 - learning_rate: 0.0010
# Epoch 8/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2706 - mae: 0.1750 - val_loss: 0.1419 - val_mae: 0.1203 - learning_rate: 0.0010
# Epoch 9/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2628 - mae: 0.1729 - val_loss: 0.1237 - val_mae: 0.1109 - learning_rate: 0.0010
# Epoch 10/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2533 - mae: 0.1708 - val_loss: 0.1235 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 11/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2491 - mae: 0.1683 - val_loss: 0.1222 - val_mae: 0.1121 - learning_rate: 0.0010
# Epoch 12/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2430 - mae: 0.1674 - val_loss: 0.1205 - val_mae: 0.1094 - learning_rate: 0.0010
# Epoch 13/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2351 - mae: 0.1661 - val_loss: 0.1134 - val_mae: 0.1083 - learning_rate: 0.0010
# Epoch 14/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2303 - mae: 0.1639 - val_loss: 0.1166 - val_mae: 0.1053 - learning_rate: 0.0010
# Epoch 15/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.2234 - mae: 0.1631 - val_loss: 0.1266 - val_mae: 0.1163 - learning_rate: 0.0010
# Epoch 16/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2177 - mae: 0.1619 - val_loss: 0.1570 - val_mae: 0.1130 - learning_rate: 0.0010
# Epoch 17/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2179 - mae: 0.1604 - val_loss: 0.1303 - val_mae: 0.1070 - learning_rate: 0.0010
# Epoch 18/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2117 - mae: 0.1588 - val_loss: 0.1395 - val_mae: 0.1081 - learning_rate: 0.0010
# Epoch 19/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2115 - mae: 0.1568 - val_loss: 0.1245 - val_mae: 0.1057 - learning_rate: 0.0010
# Epoch 20/300
# 702/709 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1788 - mae: 0.1551
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2046 - mae: 0.1554 - val_loss: 0.1253 - val_mae: 0.1153 - learning_rate: 0.0010
# Epoch 21/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.2005 - mae: 0.1542 - val_loss: 0.1080 - val_mae: 0.1044 - learning_rate: 5.0000e-04
# Epoch 22/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.2029 - mae: 0.1533 - val_loss: 0.1006 - val_mae: 0.1008 - learning_rate: 5.0000e-04
# Epoch 23/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.2010 - mae: 0.1521 - val_loss: 0.1039 - val_mae: 0.1040 - learning_rate: 5.0000e-04
# Epoch 24/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.1991 - mae: 0.1516 - val_loss: 0.1111 - val_mae: 0.1047 - learning_rate: 5.0000e-04
# Epoch 25/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1963 - mae: 0.1513 - val_loss: 0.1232 - val_mae: 0.1020 - learning_rate: 5.0000e-04
# Epoch 26/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1920 - mae: 0.1506 - val_loss: 0.1017 - val_mae: 0.0998 - learning_rate: 5.0000e-04
# Epoch 27/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1888 - mae: 0.1499 - val_loss: 0.0998 - val_mae: 0.0998 - learning_rate: 5.0000e-04
# Epoch 28/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1962 - mae: 0.1499 - val_loss: 0.0986 - val_mae: 0.0997 - learning_rate: 5.0000e-04
# Epoch 29/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1927 - mae: 0.1488 - val_loss: 0.1008 - val_mae: 0.1013 - learning_rate: 5.0000e-04
# Epoch 30/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1937 - mae: 0.1485 - val_loss: 0.0984 - val_mae: 0.0986 - learning_rate: 5.0000e-04
# Epoch 31/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.1883 - mae: 0.1478 - val_loss: 0.0971 - val_mae: 0.0990 - learning_rate: 5.0000e-04
# Epoch 32/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1865 - mae: 0.1472 - val_loss: 0.0997 - val_mae: 0.1006 - learning_rate: 5.0000e-04
# Epoch 33/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.1913 - mae: 0.1470 - val_loss: 0.0992 - val_mae: 0.1014 - learning_rate: 5.0000e-04
# Epoch 34/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1871 - mae: 0.1462 - val_loss: 0.1002 - val_mae: 0.1021 - learning_rate: 5.0000e-04
# Epoch 35/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1982 - mae: 0.1462 - val_loss: 0.0995 - val_mae: 0.0963 - learning_rate: 5.0000e-04
# Epoch 36/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1912 - mae: 0.1454 - val_loss: 0.0918 - val_mae: 0.0950 - learning_rate: 5.0000e-04
# Epoch 37/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1923 - mae: 0.1451 - val_loss: 0.0993 - val_mae: 0.0962 - learning_rate: 5.0000e-04
# Epoch 38/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1901 - mae: 0.1449 - val_loss: 0.0956 - val_mae: 0.0969 - learning_rate: 5.0000e-04
# Epoch 39/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1903 - mae: 0.1442 - val_loss: 0.1057 - val_mae: 0.0992 - learning_rate: 5.0000e-04
# Epoch 40/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1856 - mae: 0.1434 - val_loss: 0.0971 - val_mae: 0.0967 - learning_rate: 5.0000e-04
# Epoch 41/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1845 - mae: 0.1432 - val_loss: 0.0977 - val_mae: 0.0974 - learning_rate: 5.0000e-04
# Epoch 42/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1875 - mae: 0.1428 - val_loss: 0.1054 - val_mae: 0.1029 - learning_rate: 5.0000e-04
# Epoch 43/300
# 704/709 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1703 - mae: 0.1431
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1864 - mae: 0.1426 - val_loss: 0.0990 - val_mae: 0.1021 - learning_rate: 5.0000e-04
# Epoch 44/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1836 - mae: 0.1412 - val_loss: 0.0988 - val_mae: 0.0979 - learning_rate: 2.5000e-04
# Epoch 45/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1835 - mae: 0.1412 - val_loss: 0.0966 - val_mae: 0.0949 - learning_rate: 2.5000e-04
# Epoch 46/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1864 - mae: 0.1409 - val_loss: 0.0925 - val_mae: 0.0947 - learning_rate: 2.5000e-04
# Epoch 47/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1844 - mae: 0.1405 - val_loss: 0.0884 - val_mae: 0.0931 - learning_rate: 2.5000e-04
# Epoch 48/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 0.1841 - mae: 0.1404 - val_loss: 0.0899 - val_mae: 0.0941 - learning_rate: 2.5000e-04
# Epoch 49/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 0.1795 - mae: 0.1402 - val_loss: 0.0964 - val_mae: 0.0955 - learning_rate: 2.5000e-04
# Epoch 50/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 0.1894 - mae: 0.1402 - val_loss: 0.0916 - val_mae: 0.0930 - learning_rate: 2.5000e-04
# Epoch 51/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 0.1814 - mae: 0.1401 - val_loss: 0.0885 - val_mae: 0.0927 - learning_rate: 2.5000e-04
# Epoch 52/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1848 - mae: 0.1398 - val_loss: 0.0897 - val_mae: 0.0941 - learning_rate: 2.5000e-04
# Epoch 53/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 0.1821 - mae: 0.1392 - val_loss: 0.0924 - val_mae: 0.0953 - learning_rate: 2.5000e-04
# Epoch 54/300
# 708/709 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2493 - mae: 0.1388
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 0.1793 - mae: 0.1389 - val_loss: 0.0979 - val_mae: 0.0973 - learning_rate: 2.5000e-04
# Epoch 55/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 0.1816 - mae: 0.1387 - val_loss: 0.0919 - val_mae: 0.0934 - learning_rate: 1.2500e-04
# Epoch 56/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1827 - mae: 0.1386 - val_loss: 0.0873 - val_mae: 0.0925 - learning_rate: 1.2500e-04
# Epoch 57/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 0.1814 - mae: 0.1385 - val_loss: 0.0901 - val_mae: 0.0935 - learning_rate: 1.2500e-04
# Epoch 58/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 0.1840 - mae: 0.1385 - val_loss: 0.0876 - val_mae: 0.0929 - learning_rate: 1.2500e-04
# Epoch 59/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 0.1812 - mae: 0.1383 - val_loss: 0.0889 - val_mae: 0.0927 - learning_rate: 1.2500e-04
# Epoch 60/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1809 - mae: 0.1380 - val_loss: 0.0881 - val_mae: 0.0927 - learning_rate: 1.2500e-04
# Epoch 61/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1776 - mae: 0.1378 - val_loss: 0.0868 - val_mae: 0.0915 - learning_rate: 1.2500e-04
# Epoch 62/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1778 - mae: 0.1378 - val_loss: 0.0918 - val_mae: 0.0927 - learning_rate: 1.2500e-04
# Epoch 63/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1783 - mae: 0.1378 - val_loss: 0.0905 - val_mae: 0.0934 - learning_rate: 1.2500e-04
# Epoch 64/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1825 - mae: 0.1377 - val_loss: 0.0881 - val_mae: 0.0915 - learning_rate: 1.2500e-04
# Epoch 65/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1778 - mae: 0.1376 - val_loss: 0.0869 - val_mae: 0.0909 - learning_rate: 1.2500e-04
# Epoch 66/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1788 - mae: 0.1372 - val_loss: 0.0896 - val_mae: 0.0925 - learning_rate: 1.2500e-04
# Epoch 67/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1780 - mae: 0.1372 - val_loss: 0.0866 - val_mae: 0.0921 - learning_rate: 1.2500e-04
# Epoch 68/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1835 - mae: 0.1374 - val_loss: 0.0881 - val_mae: 0.0917 - learning_rate: 1.2500e-04
# Epoch 69/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1822 - mae: 0.1374 - val_loss: 0.0890 - val_mae: 0.0922 - learning_rate: 1.2500e-04
# Epoch 70/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1783 - mae: 0.1372 - val_loss: 0.0861 - val_mae: 0.0908 - learning_rate: 1.2500e-04
# Epoch 71/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1809 - mae: 0.1371 - val_loss: 0.0890 - val_mae: 0.0923 - learning_rate: 1.2500e-04
# Epoch 72/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1892 - mae: 0.1375 - val_loss: 0.0906 - val_mae: 0.0935 - learning_rate: 1.2500e-04
# Epoch 73/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1760 - mae: 0.1366 - val_loss: 0.0870 - val_mae: 0.0916 - learning_rate: 1.2500e-04
# Epoch 74/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1824 - mae: 0.1370 - val_loss: 0.0870 - val_mae: 0.0907 - learning_rate: 1.2500e-04
# Epoch 75/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1785 - mae: 0.1369 - val_loss: 0.0854 - val_mae: 0.0910 - learning_rate: 1.2500e-04
# Epoch 76/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1828 - mae: 0.1367 - val_loss: 0.0894 - val_mae: 0.0936 - learning_rate: 1.2500e-04
# Epoch 77/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1831 - mae: 0.1366 - val_loss: 0.0917 - val_mae: 0.0944 - learning_rate: 1.2500e-04
# Epoch 78/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1810 - mae: 0.1365 - val_loss: 0.0881 - val_mae: 0.0923 - learning_rate: 1.2500e-04
# Epoch 79/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1789 - mae: 0.1365 - val_loss: 0.0854 - val_mae: 0.0903 - learning_rate: 1.2500e-04
# Epoch 80/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1808 - mae: 0.1362 - val_loss: 0.0852 - val_mae: 0.0901 - learning_rate: 1.2500e-04
# Epoch 81/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1766 - mae: 0.1362 - val_loss: 0.0879 - val_mae: 0.0920 - learning_rate: 1.2500e-04
# Epoch 82/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1794 - mae: 0.1361 - val_loss: 0.0870 - val_mae: 0.0916 - learning_rate: 1.2500e-04
# Epoch 83/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1792 - mae: 0.1361 - val_loss: 0.0865 - val_mae: 0.0908 - learning_rate: 1.2500e-04
# Epoch 84/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1732 - mae: 0.1357 - val_loss: 0.0861 - val_mae: 0.0913 - learning_rate: 1.2500e-04
# Epoch 85/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1781 - mae: 0.1360 - val_loss: 0.0843 - val_mae: 0.0898 - learning_rate: 1.2500e-04
# Epoch 86/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1764 - mae: 0.1356 - val_loss: 0.0894 - val_mae: 0.0927 - learning_rate: 1.2500e-04
# Epoch 87/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1780 - mae: 0.1360 - val_loss: 0.0863 - val_mae: 0.0904 - learning_rate: 1.2500e-04
# Epoch 88/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1800 - mae: 0.1358 - val_loss: 0.0883 - val_mae: 0.0922 - learning_rate: 1.2500e-04
# Epoch 89/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.1778 - mae: 0.1356 - val_loss: 0.0845 - val_mae: 0.0901 - learning_rate: 1.2500e-04
# Epoch 90/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1874 - mae: 0.1356 - val_loss: 0.0888 - val_mae: 0.0920 - learning_rate: 1.2500e-04
# Epoch 91/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1773 - mae: 0.1358 - val_loss: 0.0884 - val_mae: 0.0911 - learning_rate: 1.2500e-04
# Epoch 92/300
# 705/709 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1830 - mae: 0.1355
# Epoch 92: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1790 - mae: 0.1353 - val_loss: 0.0913 - val_mae: 0.0932 - learning_rate: 1.2500e-04
# Epoch 93/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1795 - mae: 0.1355 - val_loss: 0.0864 - val_mae: 0.0907 - learning_rate: 6.2500e-05
# Epoch 94/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1758 - mae: 0.1351 - val_loss: 0.0881 - val_mae: 0.0922 - learning_rate: 6.2500e-05
# Epoch 95/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1759 - mae: 0.1351 - val_loss: 0.0873 - val_mae: 0.0919 - learning_rate: 6.2500e-05
# Epoch 96/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1758 - mae: 0.1350 - val_loss: 0.0843 - val_mae: 0.0895 - learning_rate: 6.2500e-05
# Epoch 97/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1746 - mae: 0.1349 - val_loss: 0.0910 - val_mae: 0.0938 - learning_rate: 6.2500e-05
# Epoch 98/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1795 - mae: 0.1352 - val_loss: 0.0840 - val_mae: 0.0899 - learning_rate: 6.2500e-05
# Epoch 99/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1755 - mae: 0.1351 - val_loss: 0.0896 - val_mae: 0.0935 - learning_rate: 6.2500e-05
# Epoch 100/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1767 - mae: 0.1350 - val_loss: 0.0848 - val_mae: 0.0897 - learning_rate: 6.2500e-05
# Epoch 101/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1754 - mae: 0.1349 - val_loss: 0.0851 - val_mae: 0.0899 - learning_rate: 6.2500e-05
# Epoch 102/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1808 - mae: 0.1350 - val_loss: 0.0865 - val_mae: 0.0912 - learning_rate: 6.2500e-05
# Epoch 103/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1773 - mae: 0.1349 - val_loss: 0.0838 - val_mae: 0.0893 - learning_rate: 6.2500e-05
# Epoch 104/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1788 - mae: 0.1349 - val_loss: 0.0854 - val_mae: 0.0904 - learning_rate: 6.2500e-05
# Epoch 105/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1759 - mae: 0.1348 - val_loss: 0.0858 - val_mae: 0.0905 - learning_rate: 6.2500e-05
# Epoch 106/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1772 - mae: 0.1346 - val_loss: 0.0849 - val_mae: 0.0902 - learning_rate: 6.2500e-05
# Epoch 107/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1774 - mae: 0.1347 - val_loss: 0.0856 - val_mae: 0.0903 - learning_rate: 6.2500e-05
# Epoch 108/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1802 - mae: 0.1349 - val_loss: 0.0867 - val_mae: 0.0910 - learning_rate: 6.2500e-05
# Epoch 109/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 0.1791 - mae: 0.1346 - val_loss: 0.0870 - val_mae: 0.0914 - learning_rate: 6.2500e-05
# Epoch 110/300
# 707/709 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1696 - mae: 0.1348
# Epoch 110: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1760 - mae: 0.1347 - val_loss: 0.0845 - val_mae: 0.0897 - learning_rate: 6.2500e-05
# Epoch 111/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1757 - mae: 0.1345 - val_loss: 0.0838 - val_mae: 0.0890 - learning_rate: 3.1250e-05
# Epoch 112/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1807 - mae: 0.1344 - val_loss: 0.0843 - val_mae: 0.0894 - learning_rate: 3.1250e-05
# Epoch 113/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 0.1781 - mae: 0.1345 - val_loss: 0.0837 - val_mae: 0.0894 - learning_rate: 3.1250e-05
# Epoch 114/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 0.1762 - mae: 0.1346 - val_loss: 0.0837 - val_mae: 0.0890 - learning_rate: 3.1250e-05
# Epoch 115/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 0.1797 - mae: 0.1346 - val_loss: 0.0845 - val_mae: 0.0901 - learning_rate: 3.1250e-05
# Epoch 116/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 0.1796 - mae: 0.1344 - val_loss: 0.0869 - val_mae: 0.0918 - learning_rate: 3.1250e-05
# Epoch 117/300
# 708/709 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1814 - mae: 0.1353
# Epoch 117: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 0.1744 - mae: 0.1347 - val_loss: 0.0838 - val_mae: 0.0892 - learning_rate: 3.1250e-05
# Epoch 118/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1769 - mae: 0.1345 - val_loss: 0.0851 - val_mae: 0.0901 - learning_rate: 1.5625e-05
# Epoch 119/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1758 - mae: 0.1344 - val_loss: 0.0868 - val_mae: 0.0914 - learning_rate: 1.5625e-05
# Epoch 120/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1775 - mae: 0.1342 - val_loss: 0.0884 - val_mae: 0.0928 - learning_rate: 1.5625e-05
# Epoch 121/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1801 - mae: 0.1348 - val_loss: 0.0837 - val_mae: 0.0890 - learning_rate: 1.5625e-05
# Epoch 122/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1768 - mae: 0.1346 - val_loss: 0.0853 - val_mae: 0.0904 - learning_rate: 1.5625e-05
# Epoch 123/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1772 - mae: 0.1345 - val_loss: 0.0875 - val_mae: 0.0919 - learning_rate: 1.5625e-05
# Epoch 124/300
# 705/709 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1950 - mae: 0.1344
# Epoch 124: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1761 - mae: 0.1345 - val_loss: 0.0853 - val_mae: 0.0904 - learning_rate: 1.5625e-05
# Epoch 125/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1816 - mae: 0.1346 - val_loss: 0.0855 - val_mae: 0.0907 - learning_rate: 7.8125e-06
# Epoch 126/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1744 - mae: 0.1342 - val_loss: 0.0841 - val_mae: 0.0897 - learning_rate: 7.8125e-06
# Epoch 127/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.1778 - mae: 0.1346 - val_loss: 0.0837 - val_mae: 0.0891 - learning_rate: 7.8125e-06
# Epoch 128/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1768 - mae: 0.1341 - val_loss: 0.0857 - val_mae: 0.0905 - learning_rate: 7.8125e-06
# Epoch 129/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1797 - mae: 0.1341 - val_loss: 0.0882 - val_mae: 0.0924 - learning_rate: 7.8125e-06
# Epoch 130/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1751 - mae: 0.1342 - val_loss: 0.0855 - val_mae: 0.0906 - learning_rate: 7.8125e-06
# Epoch 131/300
# 703/709 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1857 - mae: 0.1342
# Epoch 131: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.1809 - mae: 0.1346 - val_loss: 0.0870 - val_mae: 0.0919 - learning_rate: 7.8125e-06
# Epoch 132/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1794 - mae: 0.1348 - val_loss: 0.0857 - val_mae: 0.0907 - learning_rate: 3.9063e-06
# Epoch 133/300
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1774 - mae: 0.1343 - val_loss: 0.0858 - val_mae: 0.0910 - learning_rate: 3.9063e-06
# Epoch 133: early stopping
# Restoring model weights from the end of the best epoch: 113.
# Best val_loss:  0.083694 at epoch 112
# Final val_loss: 0.085806
# Stopped at epoch: 133

# %% [markdown]
# ## validation of train-val results

# %%
# After training, run this to evaluate
train_recon = model.predict(X_train_final, batch_size=512)
val_recon   = model.predict(X_val, batch_size=512)

train_mse = np.mean(np.square(X_train_final - train_recon))
val_mse   = np.mean(np.square(X_val - val_recon))

print(f"Train MSE: {train_mse:.4f}")   # target: < 0.15
print(f"Val MSE:   {val_mse:.4f}")     # target: < 0.15
print(f"Gap:       {abs(val_mse - train_mse):.4f}")  # target: < 0.05
# Out:
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Train MSE: 0.1117
# Val MSE:   0.0837
# Gap:       0.0280

# %% [markdown]
# ## save model to reduce headache

# %%
model.save('ann-iter2.keras')

# %% [markdown]
# ## testing model performance

# %% [markdown]
# ### feature analysis

# %%
train_recon = model.predict(X_train_final, batch_size=512)
errors_per_feature = np.mean(np.square(X_train_final - train_recon), axis=0)
feature_errors = pd.Series(errors_per_feature, index=X.columns).sort_values(ascending=False)

print("Top 10 worst reconstructed features:")
print(feature_errors.head(10))
print("\nBottom 10 best reconstructed features:")
print(feature_errors.tail(10))
# Out:
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# Top 10 worst reconstructed features:
# Fwd Header Length                1.182804
# min_seg_size_forward             1.153656
# Subflow Fwd Bytes                1.056401
# Bwd Header Length                0.670116
# Down/Up Ratio                    0.263482
# Init_Win_bytes_forward           0.225494
# iat_variability                  0.204231
# Destination Port                 0.130763
# Destination Port Distribution    0.122569
# act_data_pkt_fwd                 0.112171
# dtype: float64
#
# Bottom 10 best reconstructed features:
# Packet Length Std     0.026809
# Flow Duration         0.026555
# FIN Flag Count        0.025244
# Flow Bytes/s          0.024187
# payload_efficiency    0.023895
# packet_density        0.022709
# Flow Packets/s        0.022709
# ECE Flag Count        0.019045
# RST Flag Count        0.018989
# Fwd Packets/s         0.018243
# dtype: float64

# %% [markdown]
# ### Error Analysis

# %%
# ── 1. Compute reconstruction error on NORMAL training data ──
train_recon = model.predict(X_train_final, batch_size=512)
train_errors = np.mean(np.square(X_train_final - train_recon), axis=1)
# shape: (385482,) — one error score per sample
# ── 2. Visualize the error distribution ──

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.hist(train_errors, bins=100, edgecolor='black', log=True)
plt.title('Reconstruction Error Distribution (Training Data)')
plt.xlabel('MSE per Sample')
plt.ylabel('Count')
plt.axvline(np.percentile(train_errors, 95), color='orange', linestyle='--', label='95th percentile')
plt.axvline(np.percentile(train_errors, 99), color='red',    linestyle='--', label='99th percentile')
plt.legend()
plt.tight_layout()
plt.show()

# ── 3. Check percentile values ──
for p in [90, 95, 99, 99.5]:
    print(f"Percentile {p:5.1f}: {np.percentile(train_errors, p):.4f}")
# Out:
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Percentile  90.0: 0.1050
# Percentile  95.0: 0.1814
# Percentile  99.0: 0.5199
# Percentile  99.5: 0.7593

# %%
# ── 5. Score your test data ──
test_recon  = model.predict(X_test_scaled, batch_size=512)
test_errors = np.mean(np.square(X_test_scaled - test_recon), axis=1)
# Out:
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %% [markdown]
# ### ROC and PR Curves

# %%
actual_anomaly = y_test

fpr, tpr, roc_auc = compute_roc(
    actual_anomaly,
    test_errors)

# Plot ROC curve
plot_roc_curve(fpr, tpr, roc_auc, title='ROC curve')


precision, recall, pr_auc, threshold = compute_pr_auc(
    actual_anomaly,
    test_errors)
f1_scores = 2 * recall * precision / (recall + precision)
print('Best threshold: ', threshold[np.argmax(f1_scores[~np.isnan(f1_scores)])])
print('Best F1-Score: ', np.max(f1_scores[~np.isnan(f1_scores)]))
# Plot ROC curve
plot_pr_curve(precision, recall, pr_auc, title='PR curve')
# Out:
# C:\Users\Nathaniel\AppData\Local\Temp\ipykernel_15112\3851632075.py:14: RuntimeWarning: invalid value encountered in divide
#   f1_scores = 2 * recall * precision / (recall + precision)
# Best threshold:  0.35146333509295796
# Best F1-Score:  0.6388830757272266

# %% [markdown]
# ### Recall vs Precision across threshold

# %%
plt.figure(figsize=(8, 6))
plt.plot(threshold, recall[:-1], label='Recall', color='red', linewidth=2,)
plt.plot(threshold, precision[:-1], label='Precision', color='blue', linewidth=2,)
plt.xscale('log')
plt.legend()

# %% [markdown]
# ### finding threshold and classification of anomalies

# %%
from sklearn.metrics import roc_curve, f1_score

# Compute ROC curve to determine optimal threshold for binary classification
fpr, tpr, thresholds = roc_curve(y_test, test_errors)

# optimal threshold by max f1 score
optimal_threshold = threshold[np.argmax(f1_scores[~np.isnan(f1_scores)])]
print(f'Optimal Threshold: {optimal_threshold}')

# Classify anomalies
y_pred_if = (test_errors >= optimal_threshold).astype(int)
# Out:
# Optimal Threshold: 0.35146333509295796

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report

# target_names allows you to label the output for better readability
print(classification_report(y_test, y_pred_if, target_names=['Normal', 'Anomaly'],))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.98      0.94    194558
#      Anomaly       0.84      0.51      0.64     41573
#
#     accuracy                           0.90    236131
#    macro avg       0.87      0.75      0.79    236131
# weighted avg       0.89      0.90      0.89    236131

# %% [markdown]
# ### Confusion Matrix

# %%
# Confusion Matrix for Binary Classification
cm_kmeans = confusion_matrix(y_test, y_pred_if)

plt.figure(figsize=(8, 6))
sns.heatmap(cm_kmeans, annot=True, fmt='d', 
            xticklabels=['Normal', 'Attack'], 
            yticklabels=['Normal', 'Attack'], 
            cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Isolation Forest - 1st Iteration Confusion Matrix')
plt.show()
